# %%
import stable_retro as retro
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import VecFrameStack, VecVideoRecorder
import os
from stable_baselines3.common.callbacks import CheckpointCallback

# %%
game_name = "StreetFighterIISpecialChampionEdition-Genesis-v0"
log_path = os.path.join("Training", "Logs")

# %%
del env

# %%
env = DummyVecEnv([lambda: Monitor(retro.make(game=game_name, render_mode="None"))])
env = VecFrameStack(env, n_stack=4)

# %%
# model = PPO("CnnPolicy", env, verbose=1, device="mps", tensorboard_log=log_path)
checkpoint = CheckpointCallback(
    save_freq=100_000,
    save_path="./Training/Saved Models/Checkpoints",
    name_prefix="PPO_sf",
)

# %%
model.learn(total_timesteps=1000000, callback=checkpoint, progress_bar=True)
# Out:
# Logging to Training/Logs/PPO_11
# -----------------------------
# | time/              |      |
# |    fps             | 207  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 2048 |
# -----------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 58        |
# |    iterations           | 2         |
# |    time_elapsed         | 69        |
# |    total_timesteps      | 4096      |
# | train/                  |           |
# |    approx_kl            | 1.6733358 |
# |    clip_fraction        | 0.231     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.103    |
# |    explained_variance   | 0.116     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 16.4      |
# |    n_updates            | 212       |
# |    policy_gradient_loss | 0.0827    |
# |    value_loss           | 420       |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.08e+03   |
# |    ep_rew_mean          | 1.3e+03    |
# | time/                   |            |
# |    fps                  | 41         |
# |    iterations           | 3          |
# |    time_elapsed         | 146        |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.36572453 |
# |    clip_fraction        | 0.195      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.151     |
# |    explained_variance   | 0.256      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 16.8       |
# |    n_updates            | 222        |
# |    policy_gradient_loss | 0.0423     |
# |    value_loss           | 153        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.08e+03    |
# |    ep_rew_mean          | 1.3e+03     |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 4           |
# |    time_elapsed         | 216         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.018136589 |
# |    clip_fraction        | 0.0328      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0515     |
# |    explained_variance   | 0.0229      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.14e+03    |
# |    n_updates            | 232         |
# |    policy_gradient_loss | 0.000689    |
# |    value_loss           | 1.32e+03    |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 6.08e+03 |
# |    ep_rew_mean          | 1.3e+03  |
# | time/                   |          |
# |    fps                  | 37       |
# |    iterations           | 5        |
# |    time_elapsed         | 274      |
# |    total_timesteps      | 10240    |
# | train/                  |          |
# |    approx_kl            | 11.69794 |
# |    clip_fraction        | 0.298    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.0549  |
# |    explained_variance   | 0.686    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 66       |
# |    n_updates            | 242      |
# |    policy_gradient_loss | 0.103    |
# |    value_loss           | 1.08e+03 |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.51e+03   |
# |    ep_rew_mean          | 1.65e+03   |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 6          |
# |    time_elapsed         | 341        |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.52929676 |
# |    clip_fraction        | 0.0215     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.00629   |
# |    explained_variance   | 0.549      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 59.1       |
# |    n_updates            | 252        |
# |    policy_gradient_loss | 0.0658     |
# |    value_loss           | 436        |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.51e+03  |
# |    ep_rew_mean          | 1.65e+03  |
# | time/                   |           |
# |    fps                  | 35        |
# |    iterations           | 7         |
# |    time_elapsed         | 406       |
# |    total_timesteps      | 14336     |
# | train/                  |           |
# |    approx_kl            | 1.6555839 |
# |    clip_fraction        | 0.243     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.136    |
# |    explained_variance   | 0.584     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 14.5      |
# |    n_updates            | 262       |
# |    policy_gradient_loss | 0.0276    |
# |    value_loss           | 297       |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.51e+03   |
# |    ep_rew_mean          | 1.65e+03   |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 8          |
# |    time_elapsed         | 455        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.08294205 |
# |    clip_fraction        | 0.0975     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.128     |
# |    explained_variance   | 0.519      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.27       |
# |    n_updates            | 272        |
# |    policy_gradient_loss | -0.0119    |
# |    value_loss           | 10.2       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.69e+03  |
# |    ep_rew_mean          | 1.77e+03  |
# | time/                   |           |
# |    fps                  | 36        |
# |    iterations           | 9         |
# |    time_elapsed         | 504       |
# |    total_timesteps      | 18432     |
# | train/                  |           |
# |    approx_kl            | 2.9357753 |
# |    clip_fraction        | 0.369     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.403    |
# |    explained_variance   | 0.509     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 12.2      |
# |    n_updates            | 282       |
# |    policy_gradient_loss | 0.0409    |
# |    value_loss           | 249       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.69e+03  |
# |    ep_rew_mean          | 1.77e+03  |
# | time/                   |           |
# |    fps                  | 37        |
# |    iterations           | 10        |
# |    time_elapsed         | 552       |
# |    total_timesteps      | 20480     |
# | train/                  |           |
# |    approx_kl            | 2.5008423 |
# |    clip_fraction        | 0.382     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.201    |
# |    explained_variance   | 0.286     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 65.2      |
# |    n_updates            | 292       |
# |    policy_gradient_loss | 0.0956    |
# |    value_loss           | 444       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.69e+03  |
# |    ep_rew_mean          | 1.77e+03  |
# | time/                   |           |
# |    fps                  | 37        |
# |    iterations           | 11        |
# |    time_elapsed         | 601       |
# |    total_timesteps      | 22528     |
# | train/                  |           |
# |    approx_kl            | 3.7686925 |
# |    clip_fraction        | 0.228     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.145    |
# |    explained_variance   | 0.533     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 26.6      |
# |    n_updates            | 302       |
# |    policy_gradient_loss | 0.0662    |
# |    value_loss           | 126       |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 5.77e+03 |
# |    ep_rew_mean          | 2.02e+03 |
# | time/                   |          |
# |    fps                  | 37       |
# |    iterations           | 12       |
# |    time_elapsed         | 654      |
# |    total_timesteps      | 24576    |
# | train/                  |          |
# |    approx_kl            | 27.47004 |
# |    clip_fraction        | 0.264    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.0107  |
# |    explained_variance   | 0.198    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 809      |
# |    n_updates            | 312      |
# |    policy_gradient_loss | 0.0358   |
# |    value_loss           | 984      |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.77e+03  |
# |    ep_rew_mean          | 2.02e+03  |
# | time/                   |           |
# |    fps                  | 37        |
# |    iterations           | 13        |
# |    time_elapsed         | 707       |
# |    total_timesteps      | 26624     |
# | train/                  |           |
# |    approx_kl            | 4.2552323 |
# |    clip_fraction        | 0.155     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0493   |
# |    explained_variance   | 0.529     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 60.6      |
# |    n_updates            | 322       |
# |    policy_gradient_loss | 0.0476    |
# |    value_loss           | 669       |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.38e+03   |
# |    ep_rew_mean          | 2.02e+03   |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 14         |
# |    time_elapsed         | 761        |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.53406894 |
# |    clip_fraction        | 0.0204     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0208    |
# |    explained_variance   | 0.561      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 43.5       |
# |    n_updates            | 332        |
# |    policy_gradient_loss | 0.0307     |
# |    value_loss           | 948        |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.38e+03  |
# |    ep_rew_mean          | 2.02e+03  |
# | time/                   |           |
# |    fps                  | 37        |
# |    iterations           | 15        |
# |    time_elapsed         | 815       |
# |    total_timesteps      | 30720     |
# | train/                  |           |
# |    approx_kl            | 1.3648794 |
# |    clip_fraction        | 0.172     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.091    |
# |    explained_variance   | 0.605     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 20.2      |
# |    n_updates            | 342       |
# |    policy_gradient_loss | 0.027     |
# |    value_loss           | 192       |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.38e+03   |
# |    ep_rew_mean          | 2.02e+03   |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 16         |
# |    time_elapsed         | 869        |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.12636599 |
# |    clip_fraction        | 0.0314     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0182    |
# |    explained_variance   | 0.797      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.55       |
# |    n_updates            | 352        |
# |    policy_gradient_loss | 0.023      |
# |    value_loss           | 474        |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.46e+03  |
# |    ep_rew_mean          | 2.02e+03  |
# | time/                   |           |
# |    fps                  | 37        |
# |    iterations           | 17        |
# |    time_elapsed         | 924       |
# |    total_timesteps      | 34816     |
# | train/                  |           |
# |    approx_kl            | 0.3222611 |
# |    clip_fraction        | 0.197     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.115    |
# |    explained_variance   | 0.833     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.95      |
# |    n_updates            | 362       |
# |    policy_gradient_loss | -0.0209   |
# |    value_loss           | 22.6      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.46e+03   |
# |    ep_rew_mean          | 2.02e+03   |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 18         |
# |    time_elapsed         | 979        |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.36259106 |
# |    clip_fraction        | 0.0611     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0116    |
# |    explained_variance   | 0.666      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 24.1       |
# |    n_updates            | 372        |
# |    policy_gradient_loss | 0.0342     |
# |    value_loss           | 518        |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.46e+03  |
# |    ep_rew_mean          | 2.02e+03  |
# | time/                   |           |
# |    fps                  | 37        |
# |    iterations           | 19        |
# |    time_elapsed         | 1035      |
# |    total_timesteps      | 38912     |
# | train/                  |           |
# |    approx_kl            | 0.3978073 |
# |    clip_fraction        | 0.172     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.114    |
# |    explained_variance   | 0.642     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 5.3       |
# |    n_updates            | 382       |
# |    policy_gradient_loss | -0.0218   |
# |    value_loss           | 18.6      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.64e+03  |
# |    ep_rew_mean          | 2.16e+03  |
# | time/                   |           |
# |    fps                  | 37        |
# |    iterations           | 20        |
# |    time_elapsed         | 1090      |
# |    total_timesteps      | 40960     |
# | train/                  |           |
# |    approx_kl            | 0.8847606 |
# |    clip_fraction        | 0.162     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.08     |
# |    explained_variance   | 0.254     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 80        |
# |    n_updates            | 392       |
# |    policy_gradient_loss | 0.00576   |
# |    value_loss           | 1.24e+03  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.64e+03  |
# |    ep_rew_mean          | 2.16e+03  |
# | time/                   |           |
# |    fps                  | 37        |
# |    iterations           | 21        |
# |    time_elapsed         | 1147      |
# |    total_timesteps      | 43008     |
# | train/                  |           |
# |    approx_kl            | 5.7769227 |
# |    clip_fraction        | 0.119     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0061   |
# |    explained_variance   | 0.117     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 396       |
# |    n_updates            | 402       |
# |    policy_gradient_loss | 0.0118    |
# |    value_loss           | 636       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.61e+03  |
# |    ep_rew_mean          | 2.2e+03   |
# | time/                   |           |
# |    fps                  | 37        |
# |    iterations           | 22        |
# |    time_elapsed         | 1204      |
# |    total_timesteps      | 45056     |
# | train/                  |           |
# |    approx_kl            | 1.1036322 |
# |    clip_fraction        | 0.185     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0543   |
# |    explained_variance   | 0.912     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 13.3      |
# |    n_updates            | 412       |
# |    policy_gradient_loss | -0.0333   |
# |    value_loss           | 42.9      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.61e+03  |
# |    ep_rew_mean          | 2.2e+03   |
# | time/                   |           |
# |    fps                  | 37        |
# |    iterations           | 23        |
# |    time_elapsed         | 1261      |
# |    total_timesteps      | 47104     |
# | train/                  |           |
# |    approx_kl            | 16.236883 |
# |    clip_fraction        | 0.186     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00868  |
# |    explained_variance   | 0.216     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 414       |
# |    n_updates            | 422       |
# |    policy_gradient_loss | 0.736     |
# |    value_loss           | 1.65e+03  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.61e+03   |
# |    ep_rew_mean          | 2.2e+03    |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 24         |
# |    time_elapsed         | 1317       |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.33864972 |
# |    clip_fraction        | 0.162      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.11      |
# |    explained_variance   | 0.86       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 38.8       |
# |    n_updates            | 432        |
# |    policy_gradient_loss | -0.0166    |
# |    value_loss           | 298        |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.64e+03  |
# |    ep_rew_mean          | 2.18e+03  |
# | time/                   |           |
# |    fps                  | 37        |
# |    iterations           | 25        |
# |    time_elapsed         | 1374      |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 3.1279192 |
# |    clip_fraction        | 0.234     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0308   |
# |    explained_variance   | 0.462     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 45.6      |
# |    n_updates            | 442       |
# |    policy_gradient_loss | 0.114     |
# |    value_loss           | 590       |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.64e+03   |
# |    ep_rew_mean          | 2.18e+03   |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 26         |
# |    time_elapsed         | 1430       |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.20923358 |
# |    clip_fraction        | 0.154      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.123     |
# |    explained_variance   | 0.885      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.8        |
# |    n_updates            | 452        |
# |    policy_gradient_loss | -0.0262    |
# |    value_loss           | 28.3       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.64e+03   |
# |    ep_rew_mean          | 2.18e+03   |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 27         |
# |    time_elapsed         | 1487       |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.51395017 |
# |    clip_fraction        | 0.443      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.2       |
# |    explained_variance   | 0.388      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 16.4       |
# |    n_updates            | 462        |
# |    policy_gradient_loss | 0.0499     |
# |    value_loss           | 480        |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.71e+03  |
# |    ep_rew_mean          | 2.21e+03  |
# | time/                   |           |
# |    fps                  | 37        |
# |    iterations           | 28        |
# |    time_elapsed         | 1544      |
# |    total_timesteps      | 57344     |
# | train/                  |           |
# |    approx_kl            | 0.6658329 |
# |    clip_fraction        | 0.212     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0931   |
# |    explained_variance   | 0.782     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 8.24      |
# |    n_updates            | 472       |
# |    policy_gradient_loss | 0.0121    |
# |    value_loss           | 24.4      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.71e+03  |
# |    ep_rew_mean          | 2.21e+03  |
# | time/                   |           |
# |    fps                  | 37        |
# |    iterations           | 29        |
# |    time_elapsed         | 1602      |
# |    total_timesteps      | 59392     |
# | train/                  |           |
# |    approx_kl            | 2.4725356 |
# |    clip_fraction        | 0.195     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0648   |
# |    explained_variance   | 0.326     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 61.4      |
# |    n_updates            | 482       |
# |    policy_gradient_loss | 0.0047    |
# |    value_loss           | 1.03e+03  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.71e+03   |
# |    ep_rew_mean          | 2.21e+03   |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 30         |
# |    time_elapsed         | 1659       |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.54982877 |
# |    clip_fraction        | 0.137      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0706    |
# |    explained_variance   | 0.321      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 18.2       |
# |    n_updates            | 492        |
# |    policy_gradient_loss | 0.00485    |
# |    value_loss           | 1.18e+03   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.71e+03  |
# |    ep_rew_mean          | 2.24e+03  |
# | time/                   |           |
# |    fps                  | 36        |
# |    iterations           | 31        |
# |    time_elapsed         | 1718      |
# |    total_timesteps      | 63488     |
# | train/                  |           |
# |    approx_kl            | 6.5243206 |
# |    clip_fraction        | 0.34      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.114    |
# |    explained_variance   | 0.625     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 11.9      |
# |    n_updates            | 502       |
# |    policy_gradient_loss | 0.228     |
# |    value_loss           | 452       |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.71e+03   |
# |    ep_rew_mean          | 2.24e+03   |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 32         |
# |    time_elapsed         | 1775       |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.18000335 |
# |    clip_fraction        | 0.0493     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0315    |
# |    explained_variance   | 0.609      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.55       |
# |    n_updates            | 512        |
# |    policy_gradient_loss | 0.0109     |
# |    value_loss           | 32.7       |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 5.71e+03      |
# |    ep_rew_mean          | 2.24e+03      |
# | time/                   |               |
# |    fps                  | 36            |
# |    iterations           | 33            |
# |    time_elapsed         | 1833          |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 1.7836581e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.000163     |
# |    explained_variance   | 0.628         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 11.5          |
# |    n_updates            | 522           |
# |    policy_gradient_loss | -7.42e-05     |
# |    value_loss           | 60.6          |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 5.71e+03       |
# |    ep_rew_mean          | 2.13e+03       |
# | time/                   |                |
# |    fps                  | 36             |
# |    iterations           | 34             |
# |    time_elapsed         | 1891           |
# |    total_timesteps      | 69632          |
# | train/                  |                |
# |    approx_kl            | -2.2323972e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -0.000375      |
# |    explained_variance   | 0.659          |
# |    learning_rate        | 0.0003         |
# |    loss                 | 2.97           |
# |    n_updates            | 532            |
# |    policy_gradient_loss | -5.57e-06      |
# |    value_loss           | 11.5           |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 5.71e+03      |
# |    ep_rew_mean          | 2.13e+03      |
# | time/                   |               |
# |    fps                  | 36            |
# |    iterations           | 35            |
# |    time_elapsed         | 1949          |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 1.3239284e-08 |
# |    clip_fraction        | 0.00415       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0015       |
# |    explained_variance   | 0.287         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 34.6          |
# |    n_updates            | 542           |
# |    policy_gradient_loss | 0.0209        |
# |    value_loss           | 816           |
# -------------------------------------------
# ---------------------------------------------
# | rollout/                |                 |
# |    ep_len_mean          | 5.71e+03        |
# |    ep_rew_mean          | 2.13e+03        |
# | time/                   |                 |
# |    fps                  | 36              |
# |    iterations           | 36              |
# |    time_elapsed         | 2007            |
# |    total_timesteps      | 73728           |
# | train/                  |                 |
# |    approx_kl            | -1.12011795e-08 |
# |    clip_fraction        | 0               |
# |    clip_range           | 0.2             |
# |    entropy_loss         | -0.000633       |
# |    explained_variance   | 0.296           |
# |    learning_rate        | 0.0003          |
# |    loss                 | 1.38            |
# |    n_updates            | 552             |
# |    policy_gradient_loss | -1.23e-05       |
# |    value_loss           | 4.02            |
# ---------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 5.69e+03      |
# |    ep_rew_mean          | 2.05e+03      |
# | time/                   |               |
# |    fps                  | 36            |
# |    iterations           | 37            |
# |    time_elapsed         | 2065          |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 2.4485863e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00446      |
# |    explained_variance   | 0.388         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.347         |
# |    n_updates            | 562           |
# |    policy_gradient_loss | 7.45e-06      |
# |    value_loss           | 5.51          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.69e+03     |
# |    ep_rew_mean          | 2.05e+03     |
# | time/                   |              |
# |    fps                  | 36           |
# |    iterations           | 38           |
# |    time_elapsed         | 2124         |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0053387685 |
# |    clip_fraction        | 0.0019       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00407     |
# |    explained_variance   | 0.566        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.54         |
# |    n_updates            | 572          |
# |    policy_gradient_loss | 0.000225     |
# |    value_loss           | 109          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.67e+03    |
# |    ep_rew_mean          | 2.04e+03    |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 39          |
# |    time_elapsed         | 2182        |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.062510855 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.21       |
# |    explained_variance   | 0.834       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.103       |
# |    n_updates            | 582         |
# |    policy_gradient_loss | -0.0415     |
# |    value_loss           | 0.983       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.67e+03   |
# |    ep_rew_mean          | 2.04e+03   |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 40         |
# |    time_elapsed         | 2240       |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.25344193 |
# |    clip_fraction        | 0.204      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0709    |
# |    explained_variance   | 0.0582     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.59       |
# |    n_updates            | 592        |
# |    policy_gradient_loss | 0.0245     |
# |    value_loss           | 718        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.55e+03   |
# |    ep_rew_mean          | 2.06e+03   |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 41         |
# |    time_elapsed         | 2298       |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.04715675 |
# |    clip_fraction        | 0.0597     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0235    |
# |    explained_variance   | 0.177      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.764      |
# |    n_updates            | 602        |
# |    policy_gradient_loss | 0.0034     |
# |    value_loss           | 386        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.55e+03   |
# |    ep_rew_mean          | 2.06e+03   |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 42         |
# |    time_elapsed         | 2357       |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.07592167 |
# |    clip_fraction        | 0.127      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0885    |
# |    explained_variance   | 0.183      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 14.6       |
# |    n_updates            | 612        |
# |    policy_gradient_loss | 0.0164     |
# |    value_loss           | 849        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.55e+03     |
# |    ep_rew_mean          | 2.06e+03     |
# | time/                   |              |
# |    fps                  | 36           |
# |    iterations           | 43           |
# |    time_elapsed         | 2415         |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0059551895 |
# |    clip_fraction        | 0.0455       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0964      |
# |    explained_variance   | 0.93         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 151          |
# |    n_updates            | 622          |
# |    policy_gradient_loss | 0.000663     |
# |    value_loss           | 138          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.55e+03   |
# |    ep_rew_mean          | 1.99e+03   |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 44         |
# |    time_elapsed         | 2474       |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.12614903 |
# |    clip_fraction        | 0.166      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.164     |
# |    explained_variance   | 0.693      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.36       |
# |    n_updates            | 632        |
# |    policy_gradient_loss | -0.0168    |
# |    value_loss           | 13.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.55e+03    |
# |    ep_rew_mean          | 1.99e+03    |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 45          |
# |    time_elapsed         | 2532        |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.106404215 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0783     |
# |    explained_variance   | 0.91        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.661       |
# |    n_updates            | 642         |
# |    policy_gradient_loss | 0.0415      |
# |    value_loss           | 82          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.55e+03    |
# |    ep_rew_mean          | 1.99e+03    |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 46          |
# |    time_elapsed         | 2589        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.053752813 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.177      |
# |    explained_variance   | 0.383       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0729      |
# |    n_updates            | 652         |
# |    policy_gradient_loss | 0.004       |
# |    value_loss           | 0.576       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.6e+03   |
# |    ep_rew_mean          | 2.05e+03  |
# | time/                   |           |
# |    fps                  | 36        |
# |    iterations           | 47        |
# |    time_elapsed         | 2647      |
# |    total_timesteps      | 96256     |
# | train/                  |           |
# |    approx_kl            | 1.6244707 |
# |    clip_fraction        | 0.116     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0201   |
# |    explained_variance   | -0.00522  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 703       |
# |    n_updates            | 662       |
# |    policy_gradient_loss | 0.0445    |
# |    value_loss           | 1.25e+03  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.6e+03    |
# |    ep_rew_mean          | 2.05e+03   |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 48         |
# |    time_elapsed         | 2704       |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.34016305 |
# |    clip_fraction        | 0.0579     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.024     |
# |    explained_variance   | 0.578      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.38       |
# |    n_updates            | 672        |
# |    policy_gradient_loss | -0.00526   |
# |    value_loss           | 212        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.6e+03     |
# |    ep_rew_mean          | 2.05e+03    |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 49          |
# |    time_elapsed         | 2763        |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.011047722 |
# |    clip_fraction        | 0.0207      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0255     |
# |    explained_variance   | 0.341       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.32        |
# |    n_updates            | 682         |
# |    policy_gradient_loss | 0.00274     |
# |    value_loss           | 7.55        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.63e+03   |
# |    ep_rew_mean          | 1.95e+03   |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 50         |
# |    time_elapsed         | 2820       |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.17592615 |
# |    clip_fraction        | 0.0971     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0481    |
# |    explained_variance   | 0.371      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.46       |
# |    n_updates            | 692        |
# |    policy_gradient_loss | 0.0257     |
# |    value_loss           | 83.2       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.63e+03   |
# |    ep_rew_mean          | 1.95e+03   |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 51         |
# |    time_elapsed         | 2878       |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.12430635 |
# |    clip_fraction        | 0.0465     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0258    |
# |    explained_variance   | 0.929      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 13.7       |
# |    n_updates            | 702        |
# |    policy_gradient_loss | 0.00225    |
# |    value_loss           | 112        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.63e+03    |
# |    ep_rew_mean          | 1.95e+03    |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 52          |
# |    time_elapsed         | 2937        |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.074371666 |
# |    clip_fraction        | 0.432       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.187      |
# |    explained_variance   | 0.599       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.153       |
# |    n_updates            | 712         |
# |    policy_gradient_loss | 0.0819      |
# |    value_loss           | 1.05        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.62e+03   |
# |    ep_rew_mean          | 1.97e+03   |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 53         |
# |    time_elapsed         | 2996       |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.45082927 |
# |    clip_fraction        | 0.136      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0382    |
# |    explained_variance   | 0.0162     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 39.7       |
# |    n_updates            | 722        |
# |    policy_gradient_loss | 0.0207     |
# |    value_loss           | 1.2e+03    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.62e+03    |
# |    ep_rew_mean          | 1.97e+03    |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 54          |
# |    time_elapsed         | 3054        |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.071650535 |
# |    clip_fraction        | 0.0311      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.013      |
# |    explained_variance   | 0.442       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.62        |
# |    n_updates            | 732         |
# |    policy_gradient_loss | 0.0215      |
# |    value_loss           | 107         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.61e+03   |
# |    ep_rew_mean          | 1.97e+03   |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 55         |
# |    time_elapsed         | 3112       |
# |    total_timesteps      | 112640     |
# | train/                  |            |
# |    approx_kl            | 0.40687266 |
# |    clip_fraction        | 0.194      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0869    |
# |    explained_variance   | 0.17       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.35       |
# |    n_updates            | 742        |
# |    policy_gradient_loss | 0.0173     |
# |    value_loss           | 777        |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.61e+03  |
# |    ep_rew_mean          | 1.97e+03  |
# | time/                   |           |
# |    fps                  | 36        |
# |    iterations           | 56        |
# |    time_elapsed         | 3171      |
# |    total_timesteps      | 114688    |
# | train/                  |           |
# |    approx_kl            | 0.4268336 |
# |    clip_fraction        | 0.158     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0684   |
# |    explained_variance   | 0.16      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.36      |
# |    n_updates            | 752       |
# |    policy_gradient_loss | 0.00939   |
# |    value_loss           | 719       |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.61e+03   |
# |    ep_rew_mean          | 1.97e+03   |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 57         |
# |    time_elapsed         | 3229       |
# |    total_timesteps      | 116736     |
# ...
# |    time_elapsed         | 28766      |
# |    total_timesteps      | 964608     |
# | train/                  |            |
# |    approx_kl            | 0.80525655 |
# |    clip_fraction        | 0.14       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0961    |
# |    explained_variance   | 0.833      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.42       |
# |    n_updates            | 4902       |
# |    policy_gradient_loss | -0.01      |
# |    value_loss           | 45.8       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.57e+03   |
# |    ep_rew_mean          | 1.74e+03   |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 472        |
# |    time_elapsed         | 28832      |
# |    total_timesteps      | 966656     |
# | train/                  |            |
# |    approx_kl            | 0.10214412 |
# |    clip_fraction        | 0.0788     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.786     |
# |    explained_variance   | 0.5        |
# |    learning_rate        | 0.0003     |
# |    loss                 | 45.4       |
# |    n_updates            | 4912       |
# |    policy_gradient_loss | 0.00621    |
# |    value_loss           | 196        |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.57e+03  |
# |    ep_rew_mean          | 1.74e+03  |
# | time/                   |           |
# |    fps                  | 33        |
# |    iterations           | 473       |
# |    time_elapsed         | 28912     |
# |    total_timesteps      | 968704    |
# | train/                  |           |
# |    approx_kl            | 0.0663468 |
# |    clip_fraction        | 0.0674    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.151    |
# |    explained_variance   | 0.899     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 4.58      |
# |    n_updates            | 4922      |
# |    policy_gradient_loss | 0.00634   |
# |    value_loss           | 324       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.57e+03  |
# |    ep_rew_mean          | 1.75e+03  |
# | time/                   |           |
# |    fps                  | 33        |
# |    iterations           | 474       |
# |    time_elapsed         | 28992     |
# |    total_timesteps      | 970752    |
# | train/                  |           |
# |    approx_kl            | 0.2590979 |
# |    clip_fraction        | 0.071     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0258   |
# |    explained_variance   | 0.743     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.41      |
# |    n_updates            | 4932      |
# |    policy_gradient_loss | 0.0627    |
# |    value_loss           | 25.4      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.57e+03  |
# |    ep_rew_mean          | 1.75e+03  |
# | time/                   |           |
# |    fps                  | 33        |
# |    iterations           | 475       |
# |    time_elapsed         | 29072     |
# |    total_timesteps      | 972800    |
# | train/                  |           |
# |    approx_kl            | 0.1432862 |
# |    clip_fraction        | 0.0676    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.761    |
# |    explained_variance   | 0.931     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.66      |
# |    n_updates            | 4942      |
# |    policy_gradient_loss | -0.00194  |
# |    value_loss           | 42.2      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.57e+03   |
# |    ep_rew_mean          | 1.75e+03   |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 476        |
# |    time_elapsed         | 29152      |
# |    total_timesteps      | 974848     |
# | train/                  |            |
# |    approx_kl            | 0.12432823 |
# |    clip_fraction        | 0.114      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.207     |
# |    explained_variance   | 0.88       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.369      |
# |    n_updates            | 4952       |
# |    policy_gradient_loss | 0.0055     |
# |    value_loss           | 3.76       |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 5.56e+03 |
# |    ep_rew_mean          | 1.76e+03 |
# | time/                   |          |
# |    fps                  | 33       |
# |    iterations           | 477      |
# |    time_elapsed         | 29227    |
# |    total_timesteps      | 976896   |
# | train/                  |          |
# |    approx_kl            | 8.794117 |
# |    clip_fraction        | 0.269    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -1.85    |
# |    explained_variance   | 0.0657   |
# |    learning_rate        | 0.0003   |
# |    loss                 | 3.17     |
# |    n_updates            | 4962     |
# |    policy_gradient_loss | 0.0976   |
# |    value_loss           | 855      |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.56e+03  |
# |    ep_rew_mean          | 1.76e+03  |
# | time/                   |           |
# |    fps                  | 33        |
# |    iterations           | 478       |
# |    time_elapsed         | 29288     |
# |    total_timesteps      | 978944    |
# | train/                  |           |
# |    approx_kl            | 0.8847513 |
# |    clip_fraction        | 0.138     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.588    |
# |    explained_variance   | 0.636     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.62      |
# |    n_updates            | 4972      |
# |    policy_gradient_loss | 0.0255    |
# |    value_loss           | 79.5      |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 5.55e+03 |
# |    ep_rew_mean          | 1.74e+03 |
# | time/                   |          |
# |    fps                  | 33       |
# |    iterations           | 479      |
# |    time_elapsed         | 29350    |
# |    total_timesteps      | 980992   |
# | train/                  |          |
# |    approx_kl            | 1.072912 |
# |    clip_fraction        | 0.165    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.106   |
# |    explained_variance   | 0.853    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 2.63     |
# |    n_updates            | 4982     |
# |    policy_gradient_loss | 0.0217   |
# |    value_loss           | 19.2     |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.55e+03   |
# |    ep_rew_mean          | 1.74e+03   |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 480        |
# |    time_elapsed         | 29411      |
# |    total_timesteps      | 983040     |
# | train/                  |            |
# |    approx_kl            | 0.52743363 |
# |    clip_fraction        | 0.127      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.782     |
# |    explained_variance   | 0.894      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.54       |
# |    n_updates            | 4992       |
# |    policy_gradient_loss | -0.00523   |
# |    value_loss           | 13.7       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.55e+03   |
# |    ep_rew_mean          | 1.73e+03   |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 481        |
# |    time_elapsed         | 29474      |
# |    total_timesteps      | 985088     |
# | train/                  |            |
# |    approx_kl            | 0.12640934 |
# |    clip_fraction        | 0.137      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.27      |
# |    explained_variance   | 0.548      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 33.6       |
# |    n_updates            | 5002       |
# |    policy_gradient_loss | 0.0196     |
# |    value_loss           | 103        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.55e+03   |
# |    ep_rew_mean          | 1.73e+03   |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 482        |
# |    time_elapsed         | 29535      |
# |    total_timesteps      | 987136     |
# | train/                  |            |
# |    approx_kl            | 0.75490195 |
# |    clip_fraction        | 0.305      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.952     |
# |    explained_variance   | 0.394      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.998      |
# |    n_updates            | 5012       |
# |    policy_gradient_loss | 0.0477     |
# |    value_loss           | 83.4       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.55e+03  |
# |    ep_rew_mean          | 1.73e+03  |
# | time/                   |           |
# |    fps                  | 33        |
# |    iterations           | 483       |
# |    time_elapsed         | 29597     |
# |    total_timesteps      | 989184    |
# | train/                  |           |
# |    approx_kl            | 0.7639617 |
# |    clip_fraction        | 0.193     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.122    |
# |    explained_variance   | 0.683     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.636     |
# |    n_updates            | 5022      |
# |    policy_gradient_loss | 0.00698   |
# |    value_loss           | 13.6      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.56e+03   |
# |    ep_rew_mean          | 1.73e+03   |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 484        |
# |    time_elapsed         | 29658      |
# |    total_timesteps      | 991232     |
# | train/                  |            |
# |    approx_kl            | 0.37358898 |
# |    clip_fraction        | 0.195      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.226     |
# |    explained_variance   | 0.892      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.65       |
# |    n_updates            | 5032       |
# |    policy_gradient_loss | 0.0172     |
# |    value_loss           | 9.31       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.56e+03   |
# |    ep_rew_mean          | 1.73e+03   |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 485        |
# |    time_elapsed         | 29719      |
# |    total_timesteps      | 993280     |
# | train/                  |            |
# |    approx_kl            | 0.15704091 |
# |    clip_fraction        | 0.208      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.951     |
# |    explained_variance   | 0.32       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 19.1       |
# |    n_updates            | 5042       |
# |    policy_gradient_loss | 0.0305     |
# |    value_loss           | 226        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.56e+03   |
# |    ep_rew_mean          | 1.73e+03   |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 486        |
# |    time_elapsed         | 29781      |
# |    total_timesteps      | 995328     |
# | train/                  |            |
# |    approx_kl            | 0.04764518 |
# |    clip_fraction        | 0.133      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.236     |
# |    explained_variance   | 0.769      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 11.9       |
# |    n_updates            | 5052       |
# |    policy_gradient_loss | 0.00602    |
# |    value_loss           | 99.4       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.57e+03   |
# |    ep_rew_mean          | 1.73e+03   |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 487        |
# |    time_elapsed         | 29843      |
# |    total_timesteps      | 997376     |
# | train/                  |            |
# |    approx_kl            | 0.36508542 |
# |    clip_fraction        | 0.358      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.261     |
# |    explained_variance   | -0.035     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.28       |
# |    n_updates            | 5062       |
# |    policy_gradient_loss | 0.0536     |
# |    value_loss           | 102        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.57e+03   |
# |    ep_rew_mean          | 1.73e+03   |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 488        |
# |    time_elapsed         | 29905      |
# |    total_timesteps      | 999424     |
# | train/                  |            |
# |    approx_kl            | 0.93570393 |
# |    clip_fraction        | 0.335      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.593     |
# |    explained_variance   | 0.149      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.2        |
# |    n_updates            | 5072       |
# |    policy_gradient_loss | 0.0911     |
# |    value_loss           | 776        |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.57e+03  |
# |    ep_rew_mean          | 1.73e+03  |
# | time/                   |           |
# |    fps                  | 33        |
# |    iterations           | 489       |
# |    time_elapsed         | 29966     |
# |    total_timesteps      | 1001472   |
# | train/                  |           |
# |    approx_kl            | 0.6530564 |
# |    clip_fraction        | 0.158     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.103    |
# |    explained_variance   | 0.297     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 4.5       |
# |    n_updates            | 5082      |
# |    policy_gradient_loss | 0.0195    |
# |    value_loss           | 537       |
# ---------------------------------------
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1,001,472/1,000,000  [ 8:19:20 < 0:00:00 , ? it/s ]

# %%
PPO_path = os.path.join("Training", "Saved Models", "PPO_Model_SF")

# %%
model.save(PPO_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model.save(PPO_path)
#
# NameError: name 'model' is not defined

# %%
del model

# %%
model = PPO.load(PPO_path, env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %%
env.close()

# %%
env_eval = DummyVecEnv([lambda: Monitor(retro.make(game=game_name, render_mode="human"))])
env_eval = VecFrameStack(env_eval, n_stack=4)

# %%
evaluate_policy(model, env_eval, n_eval_episodes=10)
# Out:
# (np.float64(1300.0), np.float64(0.0))

# %%
env_record = DummyVecEnv([lambda: Monitor(retro.make(game=game_name, render_mode="rgb_array"))])
env_record = VecFrameStack(env_record, n_stack=4)

# %%
path_1_8m = os.path.join("Training", "Saved Models", "Checkpoints", "PPO_sf_1801472_steps.zip")

# %%
model = PPO.load(path_1_8m, env_record)
# Out:
# Wrapping the env in a VecTransposeImage.

# %%
env_record = VecVideoRecorder(
    env_record,
    video_folder="./Training/Recordings",
    record_video_trigger=lambda step: step == 0,
    name_prefix="SF_Test_1_8",
    video_length=5000
)

evaluate_policy(model, env_record, n_eval_episodes=1)
env_record.close()
# Out:
# Saving video to /Users/elvincheung/PersonalProjects/nba_rl/Training/Recordings/SF_Test_1_8-step-0-to-step-5000.mp4
# MoviePy - Building video /Users/elvincheung/PersonalProjects/nba_rl/Training/Recordings/SF_Test_1_8-step-0-to-step-5000.mp4.
# MoviePy - Writing video /Users/elvincheung/PersonalProjects/nba_rl/Training/Recordings/SF_Test_1_8-step-0-to-step-5000.mp4
# MoviePy - Done !
# MoviePy - video ready /Users/elvincheung/PersonalProjects/nba_rl/Training/Recordings/SF_Test_1_8-step-0-to-step-5000.mp4

# %%
env_eval.close()

# %%
model.learn(total_timesteps=1000000, callback=checkpoint, progress_bar=True, reset_num_timesteps=False)
# Out:
# Logging to Training/Logs/PPO_11
# /Users/elvincheung/PersonalProjects/nba_rl/.venv/lib/python3.12/site-packages/rich/live.py:260: UserWarning:
# install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.57e+03 |
# |    ep_rew_mean     | 1.73e+03 |
# | time/              |          |
# |    fps             | 203      |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1003520  |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.57e+03   |
# |    ep_rew_mean          | 1.73e+03   |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 2          |
# |    time_elapsed         | 125        |
# |    total_timesteps      | 1005568    |
# | train/                  |            |
# |    approx_kl            | 0.12474652 |
# |    clip_fraction        | 0.117      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0793    |
# |    explained_variance   | 0.547      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.57       |
# |    n_updates            | 5102       |
# |    policy_gradient_loss | 0.071      |
# |    value_loss           | 64.9       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.56e+03   |
# |    ep_rew_mean          | 1.73e+03   |
# | time/                   |            |
# |    fps                  | 25         |
# |    iterations           | 3          |
# |    time_elapsed         | 240        |
# |    total_timesteps      | 1007616    |
# | train/                  |            |
# |    approx_kl            | 0.19068605 |
# |    clip_fraction        | 0.122      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.147     |
# |    explained_variance   | 0.877      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 16.3       |
# |    n_updates            | 5112       |
# |    policy_gradient_loss | 0.0172     |
# |    value_loss           | 251        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.56e+03   |
# |    ep_rew_mean          | 1.73e+03   |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 4          |
# |    time_elapsed         | 357        |
# |    total_timesteps      | 1009664    |
# | train/                  |            |
# |    approx_kl            | 0.12600222 |
# |    clip_fraction        | 0.149      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.481     |
# |    explained_variance   | 0.876      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.685      |
# |    n_updates            | 5122       |
# |    policy_gradient_loss | 0.046      |
# |    value_loss           | 8.88       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.56e+03  |
# |    ep_rew_mean          | 1.73e+03  |
# | time/                   |           |
# |    fps                  | 21        |
# |    iterations           | 5         |
# |    time_elapsed         | 476       |
# |    total_timesteps      | 1011712   |
# | train/                  |           |
# |    approx_kl            | 0.6469945 |
# |    clip_fraction        | 0.208     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.23     |
# |    explained_variance   | 0.437     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.98      |
# |    n_updates            | 5132      |
# |    policy_gradient_loss | 0.0748    |
# |    value_loss           | 422       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.57e+03  |
# |    ep_rew_mean          | 1.75e+03  |
# | time/                   |           |
# |    fps                  | 20        |
# |    iterations           | 6         |
# |    time_elapsed         | 595       |
# |    total_timesteps      | 1013760   |
# | train/                  |           |
# |    approx_kl            | 0.1540097 |
# |    clip_fraction        | 0.183     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.277    |
# |    explained_variance   | 0.863     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.77      |
# |    n_updates            | 5142      |
# |    policy_gradient_loss | 0.0281    |
# |    value_loss           | 85.6      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.57e+03  |
# |    ep_rew_mean          | 1.75e+03  |
# | time/                   |           |
# |    fps                  | 19        |
# |    iterations           | 7         |
# |    time_elapsed         | 723       |
# |    total_timesteps      | 1015808   |
# | train/                  |           |
# |    approx_kl            | 0.0460051 |
# |    clip_fraction        | 0.123     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.454    |
# |    explained_variance   | 0.95      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.526     |
# |    n_updates            | 5152      |
# |    policy_gradient_loss | 0.00897   |
# |    value_loss           | 4.73      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.57e+03   |
# |    ep_rew_mean          | 1.75e+03   |
# | time/                   |            |
# |    fps                  | 19         |
# |    iterations           | 8          |
# |    time_elapsed         | 854        |
# |    total_timesteps      | 1017856    |
# | train/                  |            |
# |    approx_kl            | 0.07511917 |
# |    clip_fraction        | 0.166      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.219     |
# |    explained_variance   | 0.673      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.06       |
# |    n_updates            | 5162       |
# |    policy_gradient_loss | 0.0208     |
# |    value_loss           | 189        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.57e+03   |
# |    ep_rew_mean          | 1.76e+03   |
# | time/                   |            |
# |    fps                  | 18         |
# |    iterations           | 9          |
# |    time_elapsed         | 1008       |
# |    total_timesteps      | 1019904    |
# | train/                  |            |
# |    approx_kl            | 0.13147259 |
# |    clip_fraction        | 0.169      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.226     |
# |    explained_variance   | 0.779      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.74       |
# |    n_updates            | 5172       |
# |    policy_gradient_loss | 0.0252     |
# |    value_loss           | 16.4       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.57e+03  |
# |    ep_rew_mean          | 1.76e+03  |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 10        |
# |    time_elapsed         | 1144      |
# |    total_timesteps      | 1021952   |
# | train/                  |           |
# |    approx_kl            | 0.4463886 |
# |    clip_fraction        | 0.292     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.646    |
# |    explained_variance   | 0.728     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 11.3      |
# |    n_updates            | 5182      |
# |    policy_gradient_loss | 0.114     |
# |    value_loss           | 110       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.55e+03  |
# |    ep_rew_mean          | 1.76e+03  |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 11        |
# |    time_elapsed         | 1321      |
# |    total_timesteps      | 1024000   |
# | train/                  |           |
# |    approx_kl            | 0.1127979 |
# |    clip_fraction        | 0.163     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.294    |
# |    explained_variance   | 0.859     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1         |
# |    n_updates            | 5192      |
# |    policy_gradient_loss | 0.00453   |
# |    value_loss           | 7.77      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.55e+03    |
# |    ep_rew_mean          | 1.76e+03    |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 12          |
# |    time_elapsed         | 1461        |
# |    total_timesteps      | 1026048     |
# | train/                  |             |
# |    approx_kl            | 0.019410478 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.638      |
# |    explained_variance   | 0.521       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.7         |
# |    n_updates            | 5202        |
# |    policy_gradient_loss | 0.00447     |
# |    value_loss           | 16.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.55e+03   |
# |    ep_rew_mean          | 1.76e+03   |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 13         |
# |    time_elapsed         | 1599       |
# |    total_timesteps      | 1028096    |
# | train/                  |            |
# |    approx_kl            | 0.07091206 |
# |    clip_fraction        | 0.156      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.237     |
# |    explained_variance   | 0.928      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.35       |
# |    n_updates            | 5212       |
# |    policy_gradient_loss | 0.00663    |
# |    value_loss           | 47.5       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.54e+03   |
# |    ep_rew_mean          | 1.75e+03   |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 14         |
# |    time_elapsed         | 1739       |
# |    total_timesteps      | 1030144    |
# | train/                  |            |
# |    approx_kl            | 0.08490976 |
# |    clip_fraction        | 0.205      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.339     |
# |    explained_variance   | 0.5        |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.41       |
# |    n_updates            | 5222       |
# |    policy_gradient_loss | -0.0017    |
# |    value_loss           | 9.94       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.54e+03   |
# |    ep_rew_mean          | 1.75e+03   |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 15         |
# |    time_elapsed         | 1881       |
# |    total_timesteps      | 1032192    |
# | train/                  |            |
# |    approx_kl            | 0.06544432 |
# |    clip_fraction        | 0.176      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.405     |
# |    explained_variance   | 0.743      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 15.9       |
# |    n_updates            | 5232       |
# |    policy_gradient_loss | 0.0161     |
# |    value_loss           | 81         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.54e+03    |
# |    ep_rew_mean          | 1.75e+03    |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 16          |
# |    time_elapsed         | 2026        |
# |    total_timesteps      | 1034240     |
# | train/                  |             |
# |    approx_kl            | 0.037326925 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.364      |
# |    explained_variance   | 0.498       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.216       |
# |    n_updates            | 5242        |
# |    policy_gradient_loss | -0.000186   |
# |    value_loss           | 6.26        |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 5.54e+03 |
# |    ep_rew_mean          | 1.75e+03 |
# | time/                   |          |
# |    fps                  | 15       |
# |    iterations           | 17       |
# |    time_elapsed         | 2211     |
# |    total_timesteps      | 1036288  |
# | train/                  |          |
# |    approx_kl            | 0.101026 |
# |    clip_fraction        | 0.226    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.583   |
# |    explained_variance   | 0.624    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 2.93     |
# |    n_updates            | 5252     |
# |    policy_gradient_loss | 0.0265   |
# |    value_loss           | 186      |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.54e+03    |
# |    ep_rew_mean          | 1.75e+03    |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 18          |
# |    time_elapsed         | 2354        |
# |    total_timesteps      | 1038336     |
# | train/                  |             |
# |    approx_kl            | 0.052433576 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.288      |
# |    explained_variance   | 0.884       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.97        |
# |    n_updates            | 5262        |
# |    policy_gradient_loss | 0.000582    |
# |    value_loss           | 57.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.55e+03   |
# |    ep_rew_mean          | 1.75e+03   |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 19         |
# |    time_elapsed         | 2498       |
# |    total_timesteps      | 1040384    |
# | train/                  |            |
# |    approx_kl            | 0.08390728 |
# |    clip_fraction        | 0.15       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.154     |
# |    explained_variance   | 0.558      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.45       |
# |    n_updates            | 5272       |
# |    policy_gradient_loss | 0.0165     |
# |    value_loss           | 26.2       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.55e+03  |
# |    ep_rew_mean          | 1.75e+03  |
# | time/                   |           |
# |    fps                  | 15        |
# |    iterations           | 20        |
# |    time_elapsed         | 2643      |
# |    total_timesteps      | 1042432   |
# | train/                  |           |
# |    approx_kl            | 0.4359628 |
# |    clip_fraction        | 0.32      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.764    |
# |    explained_variance   | 0.402     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.345     |
# |    n_updates            | 5282      |
# |    policy_gradient_loss | 0.0668    |
# |    value_loss           | 21        |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.55e+03    |
# |    ep_rew_mean          | 1.75e+03    |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 21          |
# |    time_elapsed         | 2789        |
# |    total_timesteps      | 1044480     |
# | train/                  |             |
# |    approx_kl            | 0.118547074 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.125      |
# |    explained_variance   | -0.00139    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.384       |
# |    n_updates            | 5292        |
# |    policy_gradient_loss | 0.00137     |
# |    value_loss           | 15.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.54e+03   |
# |    ep_rew_mean          | 1.75e+03   |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 22         |
# |    time_elapsed         | 2934       |
# |    total_timesteps      | 1046528    |
# | train/                  |            |
# |    approx_kl            | 0.10609068 |
# |    clip_fraction        | 0.118      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.207     |
# |    explained_variance   | 0.756      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.1        |
# |    n_updates            | 5302       |
# |    policy_gradient_loss | 0.00975    |
# |    value_loss           | 96.7       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.54e+03   |
# |    ep_rew_mean          | 1.75e+03   |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 23         |
# |    time_elapsed         | 3079       |
# |    total_timesteps      | 1048576    |
# | train/                  |            |
# |    approx_kl            | 0.43290216 |
# |    clip_fraction        | 0.295      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.831     |
# |    explained_variance   | 0.345      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.58       |
# |    n_updates            | 5312       |
# |    policy_gradient_loss | 0.0203     |
# |    value_loss           | 47.9       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.54e+03  |
# |    ep_rew_mean          | 1.75e+03  |
# | time/                   |           |
# |    fps                  | 15        |
# |    iterations           | 24        |
# |    time_elapsed         | 3224      |
# |    total_timesteps      | 1050624   |
# | train/                  |           |
# |    approx_kl            | 1.4554043 |
# |    clip_fraction        | 0.353     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.449    |
# |    explained_variance   | 0.22      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 129       |
# |    n_updates            | 5322      |
# |    policy_gradient_loss | 0.0475    |
# |    value_loss           | 462       |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.55e+03   |
# |    ep_rew_mean          | 1.76e+03   |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 25         |
# |    time_elapsed         | 3372       |
# |    total_timesteps      | 1052672    |
# | train/                  |            |
# |    approx_kl            | 0.25079098 |
# |    clip_fraction        | 0.139      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.391     |
# |    explained_variance   | 0.269      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.947      |
# |    n_updates            | 5332       |
# |    policy_gradient_loss | 0.0167     |
# |    value_loss           | 550        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.55e+03   |
# |    ep_rew_mean          | 1.76e+03   |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 26         |
# |    time_elapsed         | 3519       |
# |    total_timesteps      | 1054720    |
# | train/                  |            |
# |    approx_kl            | 0.21167274 |
# |    clip_fraction        | 0.235      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.47      |
# |    explained_variance   | 0.665      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.146      |
# |    n_updates            | 5342       |
# |    policy_gradient_loss | 0.00662    |
# |    value_loss           | 3.75       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.55e+03    |
# |    ep_rew_mean          | 1.76e+03    |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 27          |
# |    time_elapsed         | 3666        |
# |    total_timesteps      | 1056768     |
# | train/                  |             |
# |    approx_kl            | 0.073023245 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.309      |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.78        |
# |    n_updates            | 5352        |
# |    policy_gradient_loss | 0.00796     |
# |    value_loss           | 34.5        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.55e+03   |
# |    ep_rew_mean          | 1.78e+03   |
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 28         |
# |    time_elapsed         | 3900       |
# |    total_timesteps      | 1058816    |
# | train/                  |            |
# |    approx_kl            | 0.16241592 |
# |    clip_fraction        | 0.12       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.091     |
# |    explained_variance   | 0.899      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7          |
# |    n_updates            | 5362       |
# |    policy_gradient_loss | 0.0097     |
# |    value_loss           | 89.9       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.55e+03    |
# |    ep_rew_mean          | 1.78e+03    |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 29          |
# |    time_elapsed         | 4049        |
# |    total_timesteps      | 1060864     |
# | train/                  |             |
# |    approx_kl            | 0.068378285 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.457      |
# |    explained_variance   | 0.692       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.74        |
# |    n_updates            | 5372        |
# |    policy_gradient_loss | 0.00947     |
# |    value_loss           | 24.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.53e+03    |
# |    ep_rew_mean          | 1.79e+03    |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 30          |
# |    time_elapsed         | 4197        |
# |    total_timesteps      | 1062912     |
# | train/                  |             |
# |    approx_kl            | 0.062329423 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.194      |
# |    explained_variance   | 0.87        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.836       |
# |    n_updates            | 5382        |
# |    policy_gradient_loss | 0.0123      |
# |    value_loss           | 84.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.53e+03   |
# |    ep_rew_mean          | 1.79e+03   |
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 31         |
# |    time_elapsed         | 4345       |
# |    total_timesteps      | 1064960    |
# | train/                  |            |
# |    approx_kl            | 0.45274585 |
# |    clip_fraction        | 0.223      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.53      |
# |    explained_variance   | 0.423      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.356      |
# |    n_updates            | 5392       |
# |    policy_gradient_loss | 0.0641     |
# |    value_loss           | 27.7       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.53e+03  |
# |    ep_rew_mean          | 1.79e+03  |
# | time/                   |           |
# |    fps                  | 14        |
# |    iterations           | 32        |
# |    time_elapsed         | 4494      |
# |    total_timesteps      | 1067008   |
# | train/                  |           |
# |    approx_kl            | 0.5922221 |
# |    clip_fraction        | 0.357     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.505    |
# |    explained_variance   | 0.639     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 7.17      |
# |    n_updates            | 5402      |
# |    policy_gradient_loss | 0.0243    |
# |    value_loss           | 140       |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 5.52e+03 |
# |    ep_rew_mean          | 1.8e+03  |
# | time/                   |          |
# |    fps                  | 14       |
# |    iterations           | 33       |
# |    time_elapsed         | 4643     |
# |    total_timesteps      | 1069056  |
# | train/                  |          |
# |    approx_kl            | 0.579568 |
# |    clip_fraction        | 0.209    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.15    |
# |    explained_variance   | 0.535    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 16       |
# |    n_updates            | 5412     |
# |    policy_gradient_loss | 0.0368   |
# |    value_loss           | 168      |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.52e+03  |
# |    ep_rew_mean          | 1.8e+03   |
# | time/                   |           |
# |    fps                  | 14        |
# |    iterations           | 34        |
# |    time_elapsed         | 4794      |
# |    total_timesteps      | 1071104   |
# | train/                  |           |
# |    approx_kl            | 11.838484 |
# |    clip_fraction        | 0.538     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.709    |
# |    explained_variance   | 0.102     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 23.6      |
# |    n_updates            | 5422      |
# |    policy_gradient_loss | 0.0843    |
# |    value_loss           | 1.66e+03  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.52e+03  |
# |    ep_rew_mean          | 1.8e+03   |
# | time/                   |           |
# |    fps                  | 14        |
# |    iterations           | 35        |
# |    time_elapsed         | 4946      |
# |    total_timesteps      | 1073152   |
# | train/                  |           |
# |    approx_kl            | 0.2836503 |
# |    clip_fraction        | 0.11      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.12     |
# |    explained_variance   | 0.898     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 4.14      |
# |    n_updates            | 5432      |
# |    policy_gradient_loss | 0.0128    |
# |    value_loss           | 110       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.51e+03  |
# |    ep_rew_mean          | 1.81e+03  |
# | time/                   |           |
# |    fps                  | 14        |
# |    iterations           | 36        |
# |    time_elapsed         | 5096      |
# |    total_timesteps      | 1075200   |
# | train/                  |           |
# |    approx_kl            | 3.0817623 |
# |    clip_fraction        | 0.277     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0543   |
# |    explained_variance   | 0.239     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 8.3       |
# |    n_updates            | 5442      |
# |    policy_gradient_loss | 0.0484    |
# |    value_loss           | 783       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.51e+03  |
# |    ep_rew_mean          | 1.81e+03  |
# | time/                   |           |
# |    fps                  | 14        |
# |    iterations           | 37        |
# |    time_elapsed         | 5245      |
# |    total_timesteps      | 1077248   |
# | train/                  |           |
# |    approx_kl            | 1.1119957 |
# |    clip_fraction        | 0.323     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.565    |
# |    explained_variance   | 0.977     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.04      |
# |    n_updates            | 5452      |
# |    policy_gradient_loss | 0.0412    |
# |    value_loss           | 43.6      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.51e+03  |
# |    ep_rew_mean          | 1.81e+03  |
# | time/                   |           |
# |    fps                  | 14        |
# |    iterations           | 38        |
# |    time_elapsed         | 5397      |
# |    total_timesteps      | 1079296   |
# | train/                  |           |
# |    approx_kl            | 14.752922 |
# |    clip_fraction        | 0.266     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.135    |
# |    explained_variance   | 0.677     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 128       |
# |    n_updates            | 5462      |
# |    policy_gradient_loss | 0.11      |
# |    value_loss           | 448       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.51e+03  |
# |    ep_rew_mean          | 1.83e+03  |
# | time/                   |           |
# |    fps                  | 14        |
# |    iterations           | 39        |
# |    time_elapsed         | 5580      |
# |    total_timesteps      | 1081344   |
# | train/                  |           |
# |    approx_kl            | 7.5696416 |
# |    clip_fraction        | 0.173     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0518   |
# |    explained_variance   | 0.257     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 31.3      |
# |    n_updates            | 5472      |
# |    policy_gradient_loss | 0.108     |
# |    value_loss           | 713       |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.51e+03   |
# |    ep_rew_mean          | 1.83e+03   |
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 40         |
# |    time_elapsed         | 5731       |
# |    total_timesteps      | 1083392    |
# | train/                  |            |
# |    approx_kl            | 0.40999973 |
# |    clip_fraction        | 0.0986     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.103     |
# |    explained_variance   | 0.854      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.07       |
# |    n_updates            | 5482       |
# |    policy_gradient_loss | 0.025      |
# |    value_loss           | 192        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.51e+03   |
# |    ep_rew_mean          | 1.83e+03   |
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 41         |
# |    time_elapsed         | 5979       |
# |    total_timesteps      | 1085440    |
# | train/                  |            |
# |    approx_kl            | 0.32446706 |
# |    clip_fraction        | 0.24       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.185     |
# |    explained_variance   | 0.602      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.75       |
# |    n_updates            | 5492       |
# |    policy_gradient_loss | 0.0204     |
# |    value_loss           | 12.9       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.5e+03   |
# |    ep_rew_mean          | 1.83e+03  |
# | time/                   |           |
# |    fps                  | 14        |
# |    iterations           | 42        |
# |    time_elapsed         | 6131      |
# |    total_timesteps      | 1087488   |
# | train/                  |           |
# |    approx_kl            | 0.7086388 |
# |    clip_fraction        | 0.0937    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0773   |
# |    explained_variance   | 0.682     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.95      |
# |    n_updates            | 5502      |
# |    policy_gradient_loss | 0.00981   |
# |    value_loss           | 29.9      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.5e+03    |
# |    ep_rew_mean          | 1.83e+03   |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 43         |
# |    time_elapsed         | 6304       |
# |    total_timesteps      | 1089536    |
# | train/                  |            |
# |    approx_kl            | 0.59109247 |
# |    clip_fraction        | 0.199      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.186     |
# |    explained_variance   | 0.782      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 15         |
# |    n_updates            | 5512       |
# |    policy_gradient_loss | 0.0109     |
# |    value_loss           | 526        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.5e+03    |
# |    ep_rew_mean          | 1.83e+03   |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 44         |
# |    time_elapsed         | 6459       |
# |    total_timesteps      | 1091584    |
# | train/                  |            |
# |    approx_kl            | 0.19128451 |
# |    clip_fraction        | 0.106      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.11      |
# |    explained_variance   | 0.775      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.51       |
# |    n_updates            | 5522       |
# |    policy_gradient_loss | 0.000926   |
# |    value_loss           | 9.55       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.52e+03    |
# |    ep_rew_mean          | 1.82e+03    |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 45          |
# |    time_elapsed         | 6611        |
# |    total_timesteps      | 1093632     |
# | train/                  |             |
# |    approx_kl            | 0.085408196 |
# |    clip_fraction        | 0.072       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0814     |
# |    explained_variance   | 0.508       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.42        |
# |    n_updates            | 5532        |
# |    policy_gradient_loss | 0.0138      |
# |    value_loss           | 29.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.52e+03   |
# |    ep_rew_mean          | 1.82e+03   |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 46         |
# |    time_elapsed         | 6763       |
# |    total_timesteps      | 1095680    |
# | train/                  |            |
# |    approx_kl            | 0.23593791 |
# |    clip_fraction        | 0.249      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.281     |
# |    explained_variance   | 0.804      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.64       |
# |    n_updates            | 5542       |
# |    policy_gradient_loss | -0.0161    |
# |    value_loss           | 23.3       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.51e+03    |
# |    ep_rew_mean          | 1.82e+03    |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 47          |
# |    time_elapsed         | 6995        |
# |    total_timesteps      | 1097728     |
# | train/                  |             |
# |    approx_kl            | 0.038678534 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.175      |
# |    explained_variance   | 0.861       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.38        |
# |    n_updates            | 5552        |
# |    policy_gradient_loss | 0.017       |
# |    value_loss           | 8.42        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.51e+03    |
# |    ep_rew_mean          | 1.82e+03    |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 48          |
# |    time_elapsed         | 7146        |
# |    total_timesteps      | 1099776     |
# | train/                  |             |
# |    approx_kl            | 0.102438234 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.251      |
# |    explained_variance   | 0.589       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.5        |
# |    n_updates            | 5562        |
# |    policy_gradient_loss | 0.0242      |
# |    value_loss           | 450         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.51e+03   |
# |    ep_rew_mean          | 1.82e+03   |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 49         |
# |    time_elapsed         | 7299       |
# |    total_timesteps      | 1101824    |
# | train/                  |            |
# |    approx_kl            | 0.06750487 |
# |    clip_fraction        | 0.132      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.175     |
# |    explained_variance   | 0.82       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 37.4       |
# |    n_updates            | 5572       |
# |    policy_gradient_loss | 0.00948    |
# |    value_loss           | 145        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.51e+03   |
# |    ep_rew_mean          | 1.82e+03   |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 50         |
# |    time_elapsed         | 7452       |
# |    total_timesteps      | 1103872    |
# | train/                  |            |
# |    approx_kl            | 0.26736915 |
# |    clip_fraction        | 0.265      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.336     |
# |    explained_variance   | 0.786      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.93       |
# |    n_updates            | 5582       |
# |    policy_gradient_loss | 0.0209     |
# |    value_loss           | 519        |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 5.51e+03 |
# |    ep_rew_mean          | 1.82e+03 |
# | time/                   |          |
# |    fps                  | 13       |
# |    iterations           | 51       |
# |    time_elapsed         | 7602     |
# |    total_timesteps      | 1105920  |
# | train/                  |          |
# |    approx_kl            | 7.884869 |
# |    clip_fraction        | 0.337    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.25    |
# |    explained_variance   | 0.814    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 13.6     |
# |    n_updates            | 5592     |
# |    policy_gradient_loss | 0.076    |
# |    value_loss           | 218      |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.51e+03  |
# |    ep_rew_mean          | 1.85e+03  |
# | time/                   |           |
# |    fps                  | 13        |
# |    iterations           | 52        |
# |    time_elapsed         | 7754      |
# |    total_timesteps      | 1107968   |
# | train/                  |           |
# |    approx_kl            | 1.3037952 |
# |    clip_fraction        | 0.159     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.082    |
# |    explained_variance   | 0.0368    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 10.2      |
# |    n_updates            | 5602      |
# |    policy_gradient_loss | 0.0133    |
# |    value_loss           | 606       |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 5.51e+03 |
# |    ep_rew_mean          | 1.85e+03 |
# | time/                   |          |
# |    fps                  | 13       |
# |    iterations           | 53       |
# |    time_elapsed         | 7905     |
# |    total_timesteps      | 1110016  |
# | train/                  |          |
# |    approx_kl            | 4.293808 |
# |    clip_fraction        | 0.402    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.268   |
# |    explained_variance   | 0.22     |
# |    learning_rate        | 0.0003   |
# |    loss                 | 4.79     |
# |    n_updates            | 5612     |
# |    policy_gradient_loss | 0.0958   |
# |    value_loss           | 126      |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.51e+03   |
# |    ep_rew_mean          | 1.85e+03   |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 54         |
# |    time_elapsed         | 8087       |
# |    total_timesteps      | 1112064    |
# | train/                  |            |
# |    approx_kl            | 0.15470403 |
# |    clip_fraction        | 0.0361     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0228    |
# |    explained_variance   | 0.678      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.74       |
# |    n_updates            | 5622       |
# |    policy_gradient_loss | -0.00284   |
# |    value_loss           | 76         |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.5e+03    |
# |    ep_rew_mean          | 1.84e+03   |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 55         |
# |    time_elapsed         | 8238       |
# |    total_timesteps      | 1114112    |
# | train/                  |            |
# |    approx_kl            | 0.28282708 |
# |    clip_fraction        | 0.216      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.137     |
# |    explained_variance   | 0.559      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.21       |
# |    n_updates            | 5632       |
# |    policy_gradient_loss | 0.00874    |
# |    value_loss           | 30.4       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.5e+03    |
# |    ep_rew_mean          | 1.84e+03   |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 56         |
# |    time_elapsed         | 8391       |
# |    total_timesteps      | 1116160    |
# | train/                  |            |
# |    approx_kl            | 0.28021097 |
# |    clip_fraction        | 0.129      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.398     |
# |    explained_variance   | 0.466      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.418      |
# |    n_updates            | 5642       |
# |    policy_gradient_loss | 0.0206     |
# |    value_loss           | 40.5       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.5e+03    |
# |    ep_rew_mean          | 1.84e+03   |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 57         |
# |    time_elapsed         | 8544       |
# ...
# |    loss                 | 3.98       |
# |    n_updates            | 8912       |
# |    policy_gradient_loss | 0.00996    |
# |    value_loss           | 88.4       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.41e+03   |
# |    ep_rew_mean          | 1.76e+03   |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 384        |
# |    time_elapsed         | 59092      |
# |    total_timesteps      | 1787904    |
# | train/                  |            |
# |    approx_kl            | 0.29661804 |
# |    clip_fraction        | 0.0378     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0358    |
# |    explained_variance   | 0.525      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.35       |
# |    n_updates            | 8922       |
# |    policy_gradient_loss | 0.00997    |
# |    value_loss           | 140        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.41e+03   |
# |    ep_rew_mean          | 1.76e+03   |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 385        |
# |    time_elapsed         | 59241      |
# |    total_timesteps      | 1789952    |
# | train/                  |            |
# |    approx_kl            | 0.28585562 |
# |    clip_fraction        | 0.0527     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.125     |
# |    explained_variance   | 0.988      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.45       |
# |    n_updates            | 8932       |
# |    policy_gradient_loss | -0.00283   |
# |    value_loss           | 20.6       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.4e+03    |
# |    ep_rew_mean          | 1.76e+03   |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 386        |
# |    time_elapsed         | 59383      |
# |    total_timesteps      | 1792000    |
# | train/                  |            |
# |    approx_kl            | 0.18571606 |
# |    clip_fraction        | 0.0305     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0117    |
# |    explained_variance   | 0.865      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 29.5       |
# |    n_updates            | 8942       |
# |    policy_gradient_loss | 0.0111     |
# |    value_loss           | 676        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.4e+03    |
# |    ep_rew_mean          | 1.76e+03   |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 387        |
# |    time_elapsed         | 59514      |
# |    total_timesteps      | 1794048    |
# | train/                  |            |
# |    approx_kl            | 0.90899336 |
# |    clip_fraction        | 0.122      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.107     |
# |    explained_variance   | 0.829      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.22       |
# |    n_updates            | 8952       |
# |    policy_gradient_loss | -0.00825   |
# |    value_loss           | 25.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.4e+03     |
# |    ep_rew_mean          | 1.76e+03    |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 388         |
# |    time_elapsed         | 59650       |
# |    total_timesteps      | 1796096     |
# | train/                  |             |
# |    approx_kl            | 0.102853104 |
# |    clip_fraction        | 0.0276      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0054     |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.17        |
# |    n_updates            | 8962        |
# |    policy_gradient_loss | 0.0125      |
# |    value_loss           | 47.3        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.4e+03   |
# |    ep_rew_mean          | 1.77e+03  |
# | time/                   |           |
# |    fps                  | 13        |
# |    iterations           | 389       |
# |    time_elapsed         | 59904     |
# |    total_timesteps      | 1798144   |
# | train/                  |           |
# |    approx_kl            | 0.4437034 |
# |    clip_fraction        | 0.127     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0847   |
# |    explained_variance   | 0.889     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 6.39      |
# |    n_updates            | 8972      |
# |    policy_gradient_loss | 0.00451   |
# |    value_loss           | 129       |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.4e+03    |
# |    ep_rew_mean          | 1.77e+03   |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 390        |
# |    time_elapsed         | 60185      |
# |    total_timesteps      | 1800192    |
# | train/                  |            |
# |    approx_kl            | 0.27949765 |
# |    clip_fraction        | 0.0376     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0401    |
# |    explained_variance   | 0.975      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.9        |
# |    n_updates            | 8982       |
# |    policy_gradient_loss | 0.00743    |
# |    value_loss           | 121        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.39e+03   |
# |    ep_rew_mean          | 1.77e+03   |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 391        |
# |    time_elapsed         | 60381      |
# |    total_timesteps      | 1802240    |
# | train/                  |            |
# |    approx_kl            | 0.13832977 |
# |    clip_fraction        | 0.0384     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0292    |
# |    explained_variance   | 0.606      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.45       |
# |    n_updates            | 8992       |
# |    policy_gradient_loss | 0.004      |
# |    value_loss           | 121        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.39e+03   |
# |    ep_rew_mean          | 1.77e+03   |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 392        |
# |    time_elapsed         | 60529      |
# |    total_timesteps      | 1804288    |
# | train/                  |            |
# |    approx_kl            | 0.73468256 |
# |    clip_fraction        | 0.0909     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.103     |
# |    explained_variance   | 0.976      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.58       |
# |    n_updates            | 9002       |
# |    policy_gradient_loss | -0.00871   |
# |    value_loss           | 30.1       |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 5.39e+03 |
# |    ep_rew_mean          | 1.77e+03 |
# | time/                   |          |
# |    fps                  | 13       |
# |    iterations           | 393      |
# |    time_elapsed         | 60673    |
# |    total_timesteps      | 1806336  |
# | train/                  |          |
# |    approx_kl            | 5.527916 |
# |    clip_fraction        | 0.199    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.151   |
# |    explained_variance   | 0.898    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 1.78     |
# |    n_updates            | 9012     |
# |    policy_gradient_loss | -0.0243  |
# |    value_loss           | 19.7     |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 5.39e+03 |
# |    ep_rew_mean          | 1.76e+03 |
# | time/                   |          |
# |    fps                  | 13       |
# |    iterations           | 394      |
# |    time_elapsed         | 60817    |
# |    total_timesteps      | 1808384  |
# | train/                  |          |
# |    approx_kl            | 2.065904 |
# |    clip_fraction        | 0.102    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.0181  |
# |    explained_variance   | 0.53     |
# |    learning_rate        | 0.0003   |
# |    loss                 | 30.5     |
# |    n_updates            | 9022     |
# |    policy_gradient_loss | 0.00865  |
# |    value_loss           | 280      |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.39e+03   |
# |    ep_rew_mean          | 1.76e+03   |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 395        |
# |    time_elapsed         | 60959      |
# |    total_timesteps      | 1810432    |
# | train/                  |            |
# |    approx_kl            | 0.73533034 |
# |    clip_fraction        | 0.11       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.256     |
# |    explained_variance   | 0.962      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.69       |
# |    n_updates            | 9032       |
# |    policy_gradient_loss | 0.0241     |
# |    value_loss           | 44.7       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.38e+03  |
# |    ep_rew_mean          | 1.76e+03  |
# | time/                   |           |
# |    fps                  | 13        |
# |    iterations           | 396       |
# |    time_elapsed         | 61101     |
# |    total_timesteps      | 1812480   |
# | train/                  |           |
# |    approx_kl            | 0.2868569 |
# |    clip_fraction        | 0.0558    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.215    |
# |    explained_variance   | 0.905     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 7.81      |
# |    n_updates            | 9042      |
# |    policy_gradient_loss | 0.00263   |
# |    value_loss           | 469       |
# ---------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 model.learn(total_timesteps=1000000, callback=checkpoint, progress_bar=True, reset_num_timesteps=False)
#
# File ~/PersonalProjects/nba_rl/.venv/lib/python3.12/site-packages/stable_baselines3/ppo/ppo.py:311, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     302 def learn(
#     303     self: SelfPPO,
#     304     total_timesteps: int,
#    (...)    309     progress_bar: bool = False,
#     310 ) -> SelfPPO:
# --> 311     return super().learn(
#     312         total_timesteps=total_timesteps,
#     313         callback=callback,
#     314         log_interval=log_interval,
#     315         tb_log_name=tb_log_name,
#     316         reset_num_timesteps=reset_num_timesteps,
#     317         progress_bar=progress_bar,
#     318     )
#
# File ~/PersonalProjects/nba_rl/.venv/lib/python3.12/site-packages/stable_baselines3/common/on_policy_algorithm.py:324, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     321 assert self.env is not None
#     323 while self.num_timesteps < total_timesteps:
# --> 324     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     326     if not continue_training:
#     327         break
#
# File ~/PersonalProjects/nba_rl/.venv/lib/python3.12/site-packages/stable_baselines3/common/on_policy_algorithm.py:218, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     213     else:
#     214         # Otherwise, clip the actions to avoid out of bound error
#     215         # as we are sampling from an unbounded Gaussian distribution
#     216         clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 218 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     220 self.num_timesteps += env.num_envs
#     222 # Give access to local variables
#
# File ~/PersonalProjects/nba_rl/.venv/lib/python3.12/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:222, in VecEnv.step(self, actions)
#     215 """
#     216 Step the environments with the given action
#     217
#     218 :param actions: the action
#     219 :return: observation, reward, done, information
#     220 """
#     221 self.step_async(actions)
# --> 222 return self.step_wait()
#
# File ~/PersonalProjects/nba_rl/.venv/lib/python3.12/site-packages/stable_baselines3/common/vec_env/vec_transpose.py:96, in VecTransposeImage.step_wait(self)
#      95 def step_wait(self) -> VecEnvStepReturn:
# ---> 96     observations, rewards, dones, infos = self.venv.step_wait()
#      98     # Transpose the terminal observations
#      99     for idx, done in enumerate(dones):
#
# File ~/PersonalProjects/nba_rl/.venv/lib/python3.12/site-packages/stable_baselines3/common/vec_env/vec_frame_stack.py:39, in VecFrameStack.step_wait(self)
#      31 def step_wait(
#      32     self,
#      33 ) -> tuple[
#    (...)     37     list[dict[str, Any]],
#      38 ]:
# ---> 39     observations, rewards, dones, infos = self.venv.step_wait()
#      40     observations, infos = self.stacked_obs.update(observations, dones, infos)  # type: ignore[arg-type]
#      41     return observations, rewards, dones, infos
#
# File ~/PersonalProjects/nba_rl/.venv/lib/python3.12/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:59, in DummyVecEnv.step_wait(self)
#      56 def step_wait(self) -> VecEnvStepReturn:
#      57     # Avoid circular imports
#      58     for env_idx in range(self.num_envs):
# ---> 59         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(  # type: ignore[assignment]
#      60             self.actions[env_idx]
#      61         )
#      62         # convert to SB3 VecEnv api
#      63         self.buf_dones[env_idx] = terminated or truncated
#
# File ~/PersonalProjects/nba_rl/.venv/lib/python3.12/site-packages/stable_baselines3/common/monitor.py:96, in Monitor.step(self, action)
#      94 if self.needs_reset:
#      95     raise RuntimeError("Tried to step environment that needs reset")
# ---> 96 observation, reward, terminated, truncated, info = self.env.step(action)
#      97 self.rewards.append(float(reward))
#      98 if terminated or truncated:
#
# File ~/PersonalProjects/nba_rl/.venv/lib/python3.12/site-packages/stable_retro/retro_env.py:249, in RetroEnv.step(self, a)
#     247 if self.movie:
#     248     self.movie.step()
# --> 249 self.em.step()
#     250 self.data.update_ram()
#     251 ob = self._update_obs()
#
# KeyboardInterrupt:
